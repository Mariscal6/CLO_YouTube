# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import seaborn as sb

# %matplotlib inline
plt.rcParams['figure.figsize'] = (30, 50)
plt.style.use('ggplot')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import json

# %%
# Save Model Using Pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import seaborn as sb

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
import pickle

# %%
url = f"C:\\Users\\Jose Manuel\\Desktop\\Ingenieria Informatica\\BigData\\Proyecto\\CLO_YouTube\\spark\\dataStreaming1000rows.csv"
#names = ['preg', 'plas', 'pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']
df = pd.read_csv(url,sep=';')
# Suponemos que un video triunfa si tiene más visitas que la media de videos en tendencia
# por lo que las columnas que tiene relación con las visitas hay que eliminarlas.
df['test'] = np.where(df['View_count']>df['View_count'].mean(), 1, 0)
df = df.drop(columns=['Channel_subscribers', 'View_count','Like_count', 'Dislike_count','Like_count', 'Comment_count','Favorite_count'])
array = df.values
X=
df
# Out:
#           videoID              Published_at  \
# 0     5hkPDgf9qJI  2019-12-11T11:00:02.000Z
# 1     lTK-m7178-4  2019-12-11T07:13:01.000Z
# 2     r_fWTgHB4Jg  2019-12-11T07:52:02.000Z
# 3     ZF_fmBAM60I  2019-12-11T08:23:04.000Z
# 4     oi-XeCez5Hc  2019-12-11T10:00:05.000Z
# 5     PJh2Y39qt90  2019-12-10T05:55:32.000Z
# 6     FcIJmT2AcWc  2019-12-11T12:30:00.000Z
# 7     JsrDjJimJ0w  2019-12-11T10:30:01.000Z
# 8     SmmScXOocXg  2019-12-10T14:55:42.000Z
# 9     -rbscSeLB1c  2019-12-11T07:00:51.000Z
# 10    RNoZBGXQhXE  2019-12-11T10:30:01.000Z
# 11    vM_bOyc8oZ8  2019-12-10T18:06:32.000Z
# 12    p3mumG_idjU  2019-12-09T17:00:18.000Z
# 13    XWBOK2n6gpE  2019-12-10T05:39:46.000Z
# 14    kfhwwlfDHak  2019-12-11T11:00:07.000Z
# 15    IfdlBhY5zSw  2019-12-10T07:12:28.000Z
# 16    dDK7izjjx84  2019-12-10T13:00:02.000Z
# 17    yH0DGo_GpPs  2019-12-11T10:54:28.000Z
# 18    vPx6M7eTYbc  2019-12-11T07:08:34.000Z
# 19    kIPqbjjjI1Q  2019-12-10T05:00:13.000Z
# 20    pFQ-gkJ82Hg  2019-12-10T10:30:03.000Z
# 21    5cuSi2r3lZ0  2019-12-10T11:36:03.000Z
# 22    8JPpbqnBoDE  2019-12-10T11:00:01.000Z
# 23    2lwDFXQvDr8  2019-12-10T12:00:01.000Z
# 24    H5pTxwNoYb8  2019-12-10T18:00:03.000Z
# 25    luDwhzkAYlM  2019-12-10T11:36:14.000Z
# 26    lpMtW8k_RG4  2019-12-10T10:40:49.000Z
# 27    ntM_V4mlV58  2019-12-10T11:00:08.000Z
# 28    rMbfTd1mgUY  2019-12-11T01:28:06.000Z
# 29    aAVSsrOiNzE  2019-12-10T18:37:12.000Z
# ...           ...                       ...
# 1059  42Ax-Ax8kYE  2019-12-03T08:43:56.000Z
# 1060  FvdSiOh5dqo  2019-12-03T12:04:36.000Z
# 1061  syCe7zfytAM  2019-12-01T19:27:54.000Z
# 1088                                 ПУШКА
#
#                                                    Tags  Favorite_count  test
# 0     Balti,denia,hamouda,حمودة,ya lili,دنيا,2019,ne...               0     0
# 1                                                   NaN               0     0
# 2                                                   NaN               0     0
# 3                                                   NaN               0     0
# 4     تحدي,تحديات,الكنز,تحدي الكنز,البحث,البحث عن ال...               0     0
# 5                                                   NaN               0     0
# 6     اصالة,اصاله,انس مروة,اصالة و انس,انس واصالة,اص...               0     0
# 7     يوسف احمد,يوسف,احمد,اغرب المقاطع,مواقف وطرائف,...               0     0
# 8     اصالة,اصاله,انس مروة,اصالة و انس,سافرنا,بيبي,ا...               0     0
# 9                                                   NaN               0     0
# 10    حفلة,بوتيك,خوله,بدر,ريما,عزوز,جوانا,كشه,مجودي,...               0     0
# 11    شهد عملت سونار لأول مرة,كشف جنس الجنين,رح يجين...               0     0
# 12    Fouzi Torino,World,skyprod's,2020,hirak,2019,s...               0     0
# 13                                       مملحات أم وليد               0     0
# 14                                                  NaN               0     0
# 15                               cuisine melissa kahina               0     0
# 16             تحدي,rima,ريما,ريما و رامي و مونا,تحديات               0     0
# 17    سؤال يراودني,سؤال صعب,لماذا يعيش السمك في الما...               0     0
# 18    The Late Late Show,Late Late Show,James Corden...               0     1
# 19                                              ام,وليد               0     0
# 20    dstor,spase,تحدي,تحديات,دستور,سبيس,محمد طارق,ق...               0     0
# 21    ابو انس,مشيع,عائلة مشيع,#عائلة_مشيع,moshaya fa...               0     0
# 22    7-9-17,شخبار,متيم,حار,شاطح,امريكا,سعودي,تحدي,ق...               0     0
# 23    muhteşem yüzyıl,hareem al sultan,''مشاهد,هرم,و...               0     0
# 24    النوم,صحة,#daheeh #الدحيح,الكفاءة,ساعات الدوام...               0     0
# 25    mjrm,قيمز,ريان الاحمري,ريان الاحمري مجرم قيمز,...               0     0
# 26    هيا,مرام,هيا ومرام,تحدي,تحديات,عصير,تحدي العصي...               0     0
# 27    مقابلات الشارع,مقابلة,عز,عز الخد,السعودية,ترند...               0     0
# 28    برشلونة,اهداف برشلونة,برشلونة اليوم,مباراة,اهد...               0     0
# 29                                                  NaN               0     0
# ...                                                 ...             ...   ...
# 1059  Марвел,MARVEL,черная вдова,релиз,трейлер,тизер...               0     0
# 1060  элджей,как снимали,как снимали элджей,олеже эл...               0     0
# 1061  русские,фильмы,мелодрамы,в хорошем качестве,hd...               0     0
# 1062  комедии,комедия,юмор,русские комедии,фильмы,ко...               0     1
# 1063  диктор,КБ,боб,знакомьтесь боб,что если,игры ра...               0     0
# 1064  BadComedian,Евген,Bad,Comedian,Фильмы,Кино,Трэ...               0     1
# 1065  а поговорить,интервью эксклюзивное,эксклюзив,и...               0     0
# 1066  добряк,dobryak,анимация,мульт,аниме,cartoon,ка...               0     0
# 1067                                                NaN               0     0
# 1068  орел и решка,orel i reshka,орел и решка новый ...               0     0
# 1069  Гений,Гений сериал,Гений все серии,криминальны...               0     0
# 1070  герман против моти,герман амкал,герман эль кла...               0     0
# 1071  Маша Маева,маева,маша,моржиха,РАСПАКОВКА ПОДАР...               0     0
# 1072  KVN,КВН,камеди,comedy,приколы,финал,шутки,смеш...               0     1
# 1073  след,sled,sled hd,след 2019,свежие серии след,...               0     0
# 1074  дневник хача,амиран сардаров,обзор,влоги,Новое...               0     1
# 1075  нурлан сабуров,что было дальше,сабуров,labelco...               0     0
# 1076  Муж собрался на новогодний корпоратив,новогодн...               0     0
# 1077     РЕН ТВ,рен тв,новости,news,емельяненко,кокляев               0     1
# 1078  Муж подсыпал жене запрещённые препараты,44-лет...               0     0
# 1079  кашмир,обзор кашмир,кашмир веган,индийская кух...               0     0
# 1080  Super,супер,Знаменитости,Селебрити,творчество,...               0     0
# 1081  короче говоря,короче,короче говоря черная пятн...               0     0
# 1082               EvgenComedian,трансляция,BadComedian               0     0
# 1083  Емельяненко,Кокляев,нокаут,Александр Емельянен...               0     1
# 1084  Satyr,пародия,юмор,Ксения Собчак пародия,остор...               0     1
# 1085  евамиллер,xolife,ева,ева миллер,eva miller,кат...               0     0
# 1086  четыре свадьбы,идеи для свадьбы,свадьба в моск...               0     0
# 1087  Беларусь,Иван Голунов,#FreeChudentsov,Владимир...               0     0
# 1088  жидковский,жидковский интервью,жидковский пушк...               0     0
#
# [1089 rows x 8 columns]

# %%
countries={'CA':'Canadá','DE':'Alemania','FR':'Francia',
           'GB':'Reino Unido','IN':'India','JP':'Japón',
           'KR':'Korea','MX':'Mexico','RU':'Rusia',
           'US':'Estados Unidos'}
dataframes = dict()
prefijos = countries.keys()
for countrie in prefijos:
    dataframes[countrie]=pd.read_csv(f'C:\\xampp\\htdocs\\CLO_YouTube\\data\\{countrie}videos.csv',sep=',',encoding="ISO-8859-1")
    print(f'C:\\xampp\\htdocs\\CLO_YouTube\\data\\{countrie}videos.csv')
    #pd.read_csv(f'C:\\xampp\\htdocs\\CLO_YouTube\\data\\{countrie}videos.csv',sep=',')
# Out:
# C:\xampp\htdocs\CLO_YouTube\data\CAvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\DEvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\FRvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\GBvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\INvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\JPvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\KRvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\MXvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\RUvideos.csv
# C:\xampp\htdocs\CLO_YouTube\data\USvideos.csv

# %%
 dataframes['CA']['views']
# Out:
# 0        17158579
# 1         1014651
# 2         3191434
# 3         2095828
# 4        33523622
#            ...
# 40876       80685
# 40877      103339
# 40878      773347
# 40879      115225
# 40880      107392
# Name: views, Length: 40881, dtype: int64

# %%
with open(r'C:\xampp\htdocs\CLO_YouTube\data\CA_category_id.json') as json_file:
    data = json.load(json_file)
    store_list = dict()
    for item in data['items']:
        store_list[int(item['id'])] = item['snippet']['title']
    print (store_list.values())
    
for dataframe in dataframes.keys():
    dataframes[dataframe] = dataframes[dataframe].replace({"category_id": store_list})
    #dataframes[dataframe]["category_id"] = str(dataframes[dataframe]["category_id"])
    #dataframes[dataframe] = dataframes[dataframe].sort_values(by='category_id')
# Out:
# dict_values(['Film & Animation', 'Autos & Vehicles', 'Music', 'Pets & Animals', 'Sports', 'Travel & Events', 'Gaming', 'People & Blogs', 'Comedy', 'Entertainment', 'News & Politics', 'Howto & Style', 'Education', 'Science & Technology', 'Comedy', 'Shows'])

# %%
for dataframe in dataframes.keys():
    f=sb.factorplot('category_id',data=dataframes[dataframe],kind="count", aspect=3,hue_order =store_list.values(),order=store_list.values())
    f.set_xticklabels(fontsize= 11)
    plt.xlabel("Categoría")
    plt.ylabel("Número de videos en tendencias")
    plt.title(f"Número de videos en tendencias por categoría en {countries[dataframe]}") # You can comment this line out if you don't need title
    fig = plt.gcf()
    fig.set_size_inches(30, 10.5)
    fig.savefig(f'categoriaTop{dataframe}.png', dpi=100)

# %%
total_dataframe = pd.DataFrame()
for prefix in dataframes.keys():
    total_dataframe = pd.concat([total_dataframe, dataframes[prefix]])
total_dataframe['publish_time'] = total_dataframe['publish_time'].apply(lambda x: str(x)[5:7])
#total_dataframe.head()
#otal_dataframe.groupby('publish_time', as_index=False).agg({"views": "mean"})
for prefix in dataframes.keys():
    dataframes[prefix] = dataframes[prefix].apply(lambda x: str(x)[5:7])
    dataframes[prefix].groupby('publish_time').agg(
    # Get max of the duration column for each group
    numero_de_videos= ('views', "count"),
    media= ('views', "mean"),
    # Get min of the duration column for each group
    suma_de_visitas=('views', sum),
    # Get sum of the duration column for each group
    numero_likes=('likes', sum), 
    Region=prefix
)
"""total_dataframe.groupby('publish_time').agg(
    # Get max of the duration column for each group
    numero_de_videos= ('views', "count"),
    media= ('views', "mean"),
    # Get min of the duration column for each group
    suma_de_visitas=('views', sum),
    # Get sum of the duration column for each group
    numero_likes=('likes', sum), 
)
"""
#x = total_dataframe.groupby('publish_time').head()
#times = pd.to_datetime(total_dataframe.publish_time,unit='s')
#total_dataframe.dtypes
#g = total_dataframe['publish_time'].groupby(pd.Grouper(freq="M"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e96d55a9ef90> in <module>
#       1 total_dataframe = pd.DataFrame()
# ----> 2 for prefix in dataframes.keys():
#       3     total_dataframe = pd.concat([total_dataframe, dataframes[prefix]])
#       4 total_dataframe['publish_time'] = total_dataframe['publish_time'].apply(lambda x: str(x)[5:7])
#       5 #total_dataframe.head()
#
# NameError: name 'dataframes' is not defined

# %%
total_dataframe.dtypes
# Out:
# video_id                  object
# trending_date             object
# title                     object
# channel_title             object
# category_id               object
# publish_time              object
# tags                      object
# views                      int64
# likes                      int64
# dislikes                   int64
# comment_count              int64
# thumbnail_link            object
# comments_disabled           bool
# ratings_disabled            bool
# video_error_or_removed      bool
# description               object
# dtype: object
